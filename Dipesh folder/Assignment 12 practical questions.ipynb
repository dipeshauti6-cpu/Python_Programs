# %%
def message():
    print("Welcome Home")
message()
# Out:
# Welcome Home

# %%
def student(name):
    print("Student Name:", name)
student("Rahul")
# Out:
# Student Name: Rahul

# %%
def add(*num):
    print(sum(num))
add(20,30)
# Out:
# 50

# %%
def square(num):
    return num*num
n = int(input("enter the number="))
print("Sqaure Number=",square(n))
# Out:
# enter the number= 10
# Sqaure Number= 100

# %%
def check(num):
    if num%2==0:
        print("even number")
    else:
        print("odd number")
n = int(input("enter the number="))
check(n)
# Out:
# enter the number= 2
# even number

# %%
def largest(a,b,c):
    if a>b and a>c:
        print("A is largest")
    elif b>a and b>c:
        print("B is largest")
    else:
        print("C is largest")
largest(10,20,30)
# Out:
# C is largest

# %%
def factorial(num):
    fact = 1
    for i in range(1,num+1):
        fact = fact * i
    return fact 
n = int(input("enter the number="))
factorial(n)
# Out:
# enter the number= 3
# 6

# %%
def average(num):
    return sum(num)/len(num)
number = (10,20,30,40,50,60)
print("Average number=",average(number))
# Out:
# Average number= 35.0

# %%
def count_vowel(text):
    count = 0
    for i in text:
        if i in "aeiouAEIOU":
            count = count+1
    return count
word =(input("enter the text="))
print("Vowels=",count_vowel(word))
# Out:
# enter the text= Hello MIT Interns
# Vowels= 5

# %%
def divide(a, b):
    return a // b, a % b
print(divide(10, 3))
# Out:
# (3, 1)

# %%
def area(length, width):
    print("Area =",length * width)
l = int(input("Enter length="))
w = int(input("Enter width="))
area(l, w)
# Out:
# Enter length= 54
# Enter width= 47
# Area = 2538

# %%
def employee(name,age,salary):
    print("Name=",name)
    print("Age=",age)
    print("Salary=",salary)
employee(name="Dipesh",age=19,salary=400000)
# Out:
# Name= Dipesh
# Age= 19
# Salary= 400000

# %%
def simple_interest(p, r=5, t=2):
    si = (p * r * t) / 100
    print("Simple Interest=",si)
amount = int(input("Enter p="))
simple_interest(amount)
# Out:
# Enter p= 54
# Simple Interest= 5.4

# %%
def add(*num):
    print(sum(num))
add(10,20,30,40,50,60)
# Out:
# 210

# %%
def details(name,age,city):
    print("Name=",name)
    print("Age=",age)
    print("City=",city)
details(name="Dipesh",age=23,city="New York")
# Out:
# Name= Dipesh
# Age= 23
# City= New York

# %%
def default(name,country="New York"):
    print("Name=",name)
    print("Country=",country)
default("Dipesh")
# Out:
# Name= Dipesh
# Country= New York

# %%
def add(a, b):
    return a + b
def sub(a, b):
    return a - b
def mul(a, b):
    return a * b
def div(a, b):
    return a / b
x = int(input("Enter first number="))
y = int(input("Enter second number"))
print("Addition =", add(x, y))
print("Subtraction =", sub(x, y))
print("Multiplication =", mul(x, y))
print("Division =", div(x, y))
# Out:
# Enter first number= 54
# Enter second number 78
# Addition = 132
# Subtraction = -24
# Multiplication = 4212
# Division = 0.6923076923076923

# %%
def add(a, b):
    print("Answer =", a + b)
def sub(a, b):
    print("Answer =", a - b)
def mul(a, b):
    print("Answer =", a * b)
def div(a, b):
    if b != 0:
        print("Answer =", a / b)
    else:
        print("Division by zero is not possible")
def mod(a, b):
    print("Answer =", a % b)
while True:
    print("\n1. Addition\n2. Subtraction\n3. Multiplication\n4. Division\n5. Modulus\n6. Exit")
    choice = int(input("Enter your choice: "))
    if choice == 1:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
        add(num1, num2)
    elif choice == 2:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
        sub(num1, num2)
    elif choice == 3:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
        mul(num1, num2)
    elif choice == 4:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
        div(num1, num2)
    elif choice == 5:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
        mod(num1, num2)
    elif choice == 6:
        print("Thanks for visiting")
        break
    else:
        print("Invalid Choice")
# Out:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exit
# Enter your choice:  6
# Thanks for visiting

# %%
def prime(num):
    if num <= 1:
        print("Not Prime")
        return
    for i in range(2, num):
        if num % i == 0:
            print("Not Prime")
            return
    print("Prime")
n = int(input("Enter a number="))
prime(n)
# Out:
# Enter a number= 5
# Prime

# %%
def fibonacci(n):
    a = 0
    b = 1
    for i in range(n):
        print(a, end=" ")
        c = a + b
        a = b
        b = c
num = int(input("Enter number="))
fibonacci(num)
# Out:
# Enter number= 5
# 0 1 1 2 3

# %%
def palindrome(text):
    if text == text[::-1]:
        print("Palindrome")
    else:
        print("Not Palindrome")
word = input("Enter a string=")
palindrome(word)
# Out:
# Enter a string= Good Night
# Not Palindrome

# %%
def count(text):
    upper = lower = digit = special = 0
    for i in text:
        if i.isupper():
            upper += 1
        elif i.islower():
            lower += 1
        elif i.isdigit():
            digit += 1
        else:
            special += 1
    print("Uppercase =",upper)
    print("Lowercase =",lower)
    print("Digits =",digit)
    print("Special Characters =",special)
text = input("Enter a string=")
count(text)
# Out:
# Enter a string= DipeshAuti@6gmail.com
# Uppercase = 2
# Lowercase = 16
# Digits = 1
# Special Characters = 2

# %%
def result(m1, m2, m3, m4, m5):
    total = m1 + m2 + m3 + m4 + m5
    per = total / 5
    if per >= 75:
        grade = "A"
    elif per >= 60:
        grade = "B"
    elif per >= 40:
        grade = "C"
    else:
        grade = "Fail"
    print("Total =", total)
    print("Percentage =", per)
    print("Grade =", grade)
result(80, 70, 75, 85, 90)
# Out:
# Total = 400
# Percentage = 80.0
# Grade = A

# %%
def maximum(*num):
    return max(num)
print("Maximum =", maximum(4,2,5,6,9,7))
# Out:
# Maximum = 9
