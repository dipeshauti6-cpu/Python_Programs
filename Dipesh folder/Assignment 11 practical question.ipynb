# %%
students = {
    1: "Rahul",
    2: "Amit",
    3: "Sneha",
    4: "Pooja",
    5: "Rohan"
}
print(students)
# Out:
# {1: 'Rahul', 2: 'Amit', 3: 'Sneha', 4: 'Pooja', 5: 'Rohan'}

# %%
students = {
    1: "Rahul",
    2: "Amit",
    3: "Sneha",
    4: "Pooja",
    5: "Rohan"
}

print(students[2])
# Out:
# Amit

# %%
student = {
    "Name": "Rahul",
    "Age": 18
}
student["City"] = "Pune"
print(student)
# Out:
# {'Name': 'Rahul', 'Age': 18, 'City': 'Pune'}

# %%
student = {
    "Name": "Rahul",
    "Age": 18
}
student["Age"] = "19"
print(student)
# Out:
# {'Name': 'Rahul', 'Age': '19'}

# %%
student = {
    "Name": "Rahul",
    "Age": 18
}
del student["Age"]
print(student)
# Out:
# {'Name': 'Rahul'}

# %%
student = {
    "Name": "Rahul",
    "Age": 18,
    "City": "Pune"
}
for i in student:
    print(i,":",student[i])
# Out:
# Name : Rahul
# Age : 18
# City : Pune

# %%
s1 = {1,2,3,4,5}
print(s1)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1 = {1,2,3,4,5}
s1.add(6)
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1 = {1,2,3,4,5}
s1.remove(5)
print(s1)
# Out:
# {1, 2, 3, 4}

# %%
string = input("enter a string=")
count = {}
for i in string:
    if i in count:
        count[i]=count[i]+1
    else:
        count[i] = 1
print(count)
# Out:
# enter a string= hi my name is dipesh
# {'h': 2, 'i': 3, ' ': 4, 'm': 2, 'y': 1, 'n': 1, 'a': 1, 'e': 2, 's': 2, 'd': 1, 'p': 1}

# %%
dict1={"A":1,
    "B":2
    }
dict2={"C":3,
    "D":4
    }
dict1.update(dict2)
print(dict1)
# Out:
# {'A': 1, 'B': 2, 'C': 3, 'D': 4}

# %%
student = {
    "Name": "Rahul",
    "Age": 18
}
key = input("Enter key")
if key in student:
    print("Key Found")
else:
    print("Key Not Found")
# Out:
# Enter key Name
# Key Found

# %%
s1= {1, 2, 3}
s2 = {4,5,6}
print(s1 | s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1 = {1, 2,3}
s2 =  {2,3,4, 5}
print(s1-s2)
# Out:
# {1}

# %%
s1 = {1,2,3}
s2 = {3,4,5}
print(s1&s2)
# Out:
# {3}

# %%
l1 = [1,1,1,1,1,1,1,1,2,3,4,5]
s1 = set(l1)
print(s1)
# Out:
# {1, 2, 3, 4, 5}
